# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/ship-detection.zip /content

# %%
# !unzip "/content/ship-detection.zip" -d "/content/output_folder10/"
# Out:
# Archive:  /content/ship-detection.zip
#   inflating: /content/output_folder10/ship-detection/average_precision.py
#   inflating: /content/output_folder10/ship-detection/data_queue.py
#   inflating: /content/output_folder10/ship-detection/detect.py
#   inflating: /content/output_folder10/ship-detection/export_model.py
#   inflating: /content/output_folder10/ship-detection/infer.py
#   inflating: /content/output_folder10/ship-detection/pascal_summary.py
#   inflating: /content/output_folder10/ship-detection/process_dataset.py
#    creating: /content/output_folder10/ship-detection/sar_ship/
#    creating: /content/output_folder10/ship-detection/sar_ship/test/
#    creating: /content/output_folder10/ship-detection/sar_ship/test/Annotations/
#   inflating: /content/output_folder10/ship-detection/sar_ship/test/Annotations/Img1013new.xml
#   inflating: /content/output_folder10/ship-detection/sar_ship/test/Annotations/Img1028new.xml
# ...

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# %cd output_folder10
# Out:
# /content/output_folder10

# %%
# %cd ship-detection/
# Out:
# /content/output_folder10/ship-detection

# %%
# !python process_dataset.py
# Out:
# [i] Data source:           sar_ship
# [i] Data directory:        sar_ship
# [i] Validation fraction:   0.025
# [i] Expand probability:    0.5
# [i] Sampler trials:        50
# [i] Annotate:              True
# [i] Compute training data: True
# [i] Preset:                vgg300
# [i] Process test dataset:  False
# [i] Configuring the data source...
# trainval_: 100% 1197/1197 [00:01<00:00, 645.91samples/s]
# valid_: 100% 300/300 [00:00<00:00, 633.86samples/s]
# [i] # training samples:    1193
# [i] # validation samples:  299
# [i] # testing samples:     0
# [i] # classes:             1
# [i] Annotating samples...
# train: 100% 1193/1193 [00:03<00:00, 315.38samples/s]
# valid: 100% 299/299 [00:00<00:00, 321.23samples/s]

# %%
# !python train.py
# Out:
# [i] Project name:          test
# [i] Data directory:        sar_ship
# [i] VGG directory:         vgg_graph
# [i] # epochs:              200
# [i] Batch size:            8
# [i] Tensorboard directory: tb
# [i] Checkpoint interval:   5
# [i] Learning rate values:  0.00005;0.0001;0.00001
# [i] Learning rate boundaries:  320000;400000
# [i] Momentum:              0.9
# [i] Weight decay:          0.0005
# [i] Continue:              False
# [i] Number of workers:     2
# [i] Creating directory test...
# [i] Starting at epoch:     1
# [i] Configuring the training data...
# [i] # training samples:    1193
# [i] # validation samples:  299
# [i] # classes:             1
# [i] Image size:            Size(w=300, h=300)
# WARNING:tensorflow:From train.py:166: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-08-16 23:21:29.489098: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...
